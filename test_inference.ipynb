# %%
import numpy as np
import pandas as pd

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class OldDataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values

# %%
import pickle
with open ('pipeline_feature.pkl','rb') as pipe:
    pipeline_feature = pickle.load(pipe)

with open ('pipeline_model.pkl','rb') as pipe1:
    pipeline_model = pickle.load(pipe1)

# %%
# model
df = pd.read_csv('CarPrice_Assignment.csv')
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
new_data = df.sample(n=10, random_state=48)
new_data = new_data.reset_index()

# %%
new = new_data[['carlength', 'carwidth', 'curbweight', 'enginesize', 'horsepower', 'citympg','highwaympg','fueltype', 'drivewheel']]
new
# Out:
#    carlength  carwidth  curbweight  enginesize  horsepower  citympg  \
# 0      158.7      63.6        2015          92          62       31
# 1      157.3      63.8        1967          90          68       31
# 2      169.7      63.6        3110          92          62       27
# 3      172.0      65.4        2385         108          82       24
# 4      175.6      66.5        2414         122          92       27
# 5      175.4      65.2        2465         110         101       24
# 6      173.2      66.3        2833         156         145       19
# 7      144.6      63.9        1819          92          76       31
# 8      176.8      64.8        2395         108         101       23
# 9      170.2      63.8        2037          97          69       31
#
#    highwaympg fueltype drivewheel
# 0          38      gas        fwd
# 1          38      gas        fwd
# 2          32      gas        4wd
# 3          25      gas        4wd
# 4          32      gas        fwd
# ...

# %%
neww = pd.DataFrame([158.7, 63.6, 2015, 92, 62, 31, 38, 'gas', '4wd']).T
neww.columns=['carlength', 'carwidth', 'curbweight', 'enginesize', 'horsepower', 'citympg','highwaympg','fueltype', 'drivewheel']
neww
# Out:
#   carlength carwidth curbweight enginesize horsepower citympg highwaympg  \
# 0     158.7     63.6       2015         92         62      31         38
#
#   fueltype drivewheel
# 0      gas        4wd

# %%
# prediksi
new1 = pipeline_feature.transform(new)
pred = pipeline_model.predict(new1)

# %%
pred
# Out:
# array([ 6501.005     ,  6425.39166667,  9475.915     ,  9658.19666667,
#        10420.27833333, 11079.93166667, 13323.95833333,  6496.08583333,
#        13918.53166667,  7652.71833333])
